# %% [markdown]
# This code explores the maps and their intensity values.

# %%
#import global packages
import numpy as np
import astropy.io.fits as pyfits
from astropy.table import Table
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# open nebular catalog table
hdu = pyfits.open('../Data/0.Nebulae_catalogue_public.fits')
header = hdu[1].header
data = Table(hdu[1].data)
data[0:1]
# Out:
# <Table length=11111>
# gal_name region_ID ...        AV_ERR           HA6562_LUM_CORR
#  str32    float64  ...       float64               float64
# -------- --------- ... -------------------- ----------------------
#   IC5332       1.0 ...                  0.0  4.002986321046122e+35
#   IC5332       2.0 ...  0.07832516526534104  2.340213881134546e+36
#   IC5332       3.0 ...  0.04318780519771046  1.969260419879168e+37
#   IC5332       4.0 ...  0.10827729976705297 1.0172977186611461e+36
#   IC5332       5.0 ...   0.1375023823142445  7.024421842300542e+35
#   IC5332       6.0 ...                  0.0  6.355989615531316e+35
#      ...       ... ...                  ...                    ...
#  NGC1566     120.0 ... 0.006927186203987331  4.801586537280526e+38
#  NGC1566     121.0 ...  0.01794378266004939  5.179477204239551e+37
#  NGC1566     122.0 ...  0.00557714934757334 1.0319038733713389e+39
#  NGC1566     123.0 ...  0.04627216918919224 1.4771290102272536e+37
#  NGC1566     124.0 ... 0.036484358339884775 1.3028716704039092e+37
#  NGC1566     125.0 ...  0.05659932224415382  6.131513314219032e+36
#  NGC1566     126.0 ...  0.09024642512729157 3.3183702311691104e+36

# %%
hii_avs = data["AV"][np.isfinite(data["AV"])]
np.average(hii_avs)
# Out:
# 0.7922170868570743
